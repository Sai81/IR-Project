# %%
from google.colab import drive
drive.mount('/content/drive')
import os
notebook_path = os.path.abspath("IR_Project")
# Out:
# Mounted at /content/drive

# %%
import sys
import numpy as np
import pandas as pd
from matplotlib.pyplot import imread
import pickle
from os import listdir
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers import *
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform

from keras.engine import *
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import numpy.random as rng

# %%
import re
import numpy as np
from PIL import Image

from sklearn.model_selection import train_test_split
from keras import backend as K
from keras.layers import Activation
from keras.layers import Input, Lambda, Dense, Dropout, Convolution2D, MaxPooling2D, Flatten
from keras.models import Sequential, Model
from keras.optimizers import RMSprop

# %%
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array

from keras.models import Model

# %% [markdown]
# ##List Images loading

# %%
file1=open(os.path.join(os.path.dirname(notebook_path),'software/Flickr15K/list_images.txt'),'rb')
imageName=[]
arr=file1.readlines()
str(arr[0]).split(' ')[1].split('\\n')
for i in range(len(arr)):
  imageName.append(str(arr[i]).split(' ')[1].split('\\n')[0])

# %%
imageName
# Out:
# ['fire_balloon/110181.jpg',
#  'fire_balloon/129097.jpg',
#  'fire_balloon/13794.jpg',
#  'fire_balloon/138163.jpg',
#  'fire_balloon/142476.jpg',
#  'fire_balloon/142850.jpg',
#  'fire_balloon/142984.jpg',
#  'fire_balloon/143028.jpg',
#  'fire_balloon/356485.jpg',
#  'fire_balloon/356488.jpg',
#  'fire_balloon/356491.jpg',
#  'fire_balloon/356498.jpg',
#  'fire_balloon/356557.jpg',
#  'fire_balloon/366639.jpg',
#  'fire_balloon/384541.jpg',
#  'fire_balloon/390060.jpg',
#  'fire_balloon/551831.jpg',
#  'fire_balloon/551835.jpg',
#  'fire_balloon/566962.jpg',
#  'fire_balloon/60385.jpg',
#  'fire_balloon/60388.jpg',
#  'fire_balloon/73852.jpg',
#  'fire_balloon/73863.jpg',
#  'fire_balloon/81386.jpg',
#  'fire_balloon/81393.jpg',
#  'fire_balloon/90415.jpg',
#  'fire_balloon/917248.jpg',
#  'fire_balloon/917249.jpg',
#  'fire_balloon/917254.jpg',
#  'fire_balloon/947521.jpg',
#  'fire_balloon/96346.jpg',
#  'fire_balloon/96384.jpg',
#  'fire_balloon/96539.jpg',
#  'fire_balloon/97479.jpg',
#  'fire_balloon/99016.jpg',
#  'fire_balloon/990953.jpg',
#  'London_eye/1001395.jpg',
#  'London_eye/100246.jpg',
#  'London_eye/1004885.jpg',
#  'London_eye/1006701.jpg',
#  'London_eye/1006751.jpg',
#  'London_eye/1006928.jpg',
#  'London_eye/1008297.jpg',
#  'London_eye/1009216.jpg',
#  'London_eye/1009572.jpg',
#  'London_eye/1009886.jpg',
#  'London_eye/101094.jpg',
#  'London_eye/101097.jpg',
#  'London_eye/1011324.jpg',
#  'London_eye/1011369.jpg',
#  'London_eye/1012301.jpg',
#  'London_eye/1022403.jpg',
#  'London_eye/1022711.jpg',
#  'London_eye/1022871.jpg',
#  'London_eye/1023023.jpg',
#  'London_eye/1023042.jpg',
#  'London_eye/1023431.jpg',
#  'London_eye/1024164.jpg',
#  'London_eye/1024602.jpg',
#  'London_eye/1025018.jpg',
#  'London_eye/1028033.jpg',
#  'London_eye/1029967.jpg',
#  'London_eye/1030020.jpg',
#  'London_eye/1030065.jpg',
#  'London_eye/1030067.jpg',
#  'London_eye/1030988.jpg',
#  'London_eye/1031168.jpg',
#  'London_eye/1032669.jpg',
#  'London_eye/1033820.jpg',
#  'London_eye/1034356.jpg',
#  'London_eye/1038816.jpg',
#  'London_eye/1042354.jpg',
#  'London_eye/1043308.jpg',
#  'London_eye/1047159.jpg',
#  'London_eye/1048038.jpg',
#  'London_eye/1048040.jpg',
#  'London_eye/1048047.jpg',
#  'London_eye/1050380.jpg',
#  'London_eye/105068.jpg',
#  'London_eye/105069.jpg',
#  'London_eye/1051898.jpg',
#  'London_eye/1052139.jpg',
#  'London_eye/1053149.jpg',
#  'London_eye/1053541.jpg',
#  'London_eye/1056844.jpg',
#  'London_eye/1056958.jpg',
#  'London_eye/1057716.jpg',
#  'London_eye/1059926.jpg',
#  'London_eye/1060120.jpg',
#  'London_eye/1061697.jpg',
#  'London_eye/1061962.jpg',
#  'London_eye/1061980.jpg',
#  'London_eye/1063974.jpg',
#  'London_eye/10660.jpg',
#  'London_eye/106671.jpg',
#  'London_eye/10950.jpg',
#  'London_eye/1102.jpg',
#  'London_eye/113693.jpg',
#  'London_eye/141502.jpg',
#  'London_eye/141967.jpg',
#  'London_eye/14455.jpg',
#  'London_eye/148037.jpg',
#  'London_eye/149256.jpg',
#  'London_eye/15311.jpg',
#  'London_eye/164071.jpg',
#  'London_eye/16676.jpg',
#  'London_eye/167629.jpg',
#  'London_eye/168541.jpg',
#  'London_eye/168545.jpg',
#  'London_eye/168638.jpg',
#  'London_eye/168657.jpg',
#  'London_eye/168980.jpg',
#  'London_eye/170451.jpg',
#  'London_eye/173723.jpg',
#  'London_eye/173728.jpg',
#  'London_eye/173729.jpg',
#  'London_eye/174599.jpg',
#  'London_eye/174783.jpg',
#  'London_eye/174856.jpg',
#  'London_eye/175391.jpg',
#  'London_eye/175756.jpg',
#  'London_eye/175759.jpg',
#  'London_eye/176384.jpg',
#  'London_eye/177755.jpg',
#  'London_eye/177821.jpg',
#  'London_eye/177822.jpg',
#  'London_eye/177829.jpg',
#  'London_eye/178292.jpg',
#  'London_eye/180045.jpg',
#  'London_eye/180515.jpg',
#  'London_eye/180637.jpg',
#  'London_eye/184678.jpg',
#  'London_eye/188372.jpg',
#  'London_eye/188796.jpg',
#  'London_eye/190254.jpg',
#  'London_eye/190797.jpg',
#  'London_eye/190799.jpg',
#  'London_eye/190922.jpg',
#  'London_eye/191655.jpg',
#  'London_eye/196761.jpg',
#  'London_eye/197127.jpg',
#  'London_eye/197654.jpg',
#  'London_eye/197686.jpg',
#  'London_eye/203431.jpg',
#  'London_eye/207776.jpg',
#  'London_eye/20882.jpg',
#  'London_eye/209481.jpg',
#  'London_eye/211317.jpg',
#  'London_eye/212376.jpg',
#  'London_eye/216059.jpg',
#  'London_eye/216425.jpg',
#  'London_eye/220385.jpg',
#  'London_eye/221433.jpg',
#  'London_eye/222714.jpg',
#  'London_eye/225724.jpg',
#  'London_eye/225864.jpg',
#  'London_eye/226938.jpg',
#  'London_eye/229704.jpg',
#  'London_eye/230149.jpg',
#  'London_eye/231134.jpg',
#  'London_eye/231852.jpg',
#  'London_eye/232593.jpg',
#  'London_eye/232594.jpg',
#  'London_eye/233308.jpg',
#  'London_eye/233423.jpg',
#  'London_eye/233580.jpg',
#  'London_eye/233755.jpg',
#  'London_eye/234401.jpg',
#  'London_eye/234405.jpg',
#  'London_eye/234407.jpg',
#  'London_eye/234514.jpg',
#  'London_eye/234800.jpg',
#  'London_eye/234945.jpg',
#  'London_eye/234946.jpg',
#  'London_eye/234948.jpg',
#  'London_eye/234951.jpg',
#  'London_eye/235346.jpg',
#  'London_eye/236882.jpg',
#  'London_eye/237186.jpg',
#  'London_eye/238319.jpg',
#  'London_eye/24027.jpg',
#  'London_eye/240848.jpg',
#  'London_eye/241661.jpg',
#  'London_eye/242717.jpg',
#  'London_eye/245296.jpg',
#  'London_eye/246631.jpg',
#  'London_eye/247027.jpg',
#  'London_eye/247451.jpg',
#  'London_eye/25002.jpg',
#  'London_eye/25007.jpg',
#  'London_eye/25078.jpg',
#  'London_eye/252025.jpg',
#  'London_eye/252068.jpg',
#  'London_eye/252542.jpg',
#  'London_eye/252851.jpg',
#  'London_eye/252927.jpg',
#  'London_eye/253405.jpg',
#  'London_eye/253506.jpg',
#  'London_eye/253507.jpg',
#  'London_eye/253510.jpg',
#  'London_eye/253511.jpg',
#  'London_eye/253512.jpg',
#  'London_eye/253631.jpg',
#  'London_eye/253632.jpg',
#  'London_eye/253806.jpg',
#  'London_eye/253808.jpg',
#  'London_eye/253809.jpg',
#  'London_eye/253810.jpg',
#  'London_eye/254794.jpg',
#  'London_eye/254795.jpg',
#  'London_eye/254796.jpg',
#  'London_eye/254808.jpg',
#  'London_eye/254809.jpg',
#  'London_eye/254817.jpg',
#  'London_eye/254818.jpg',
#  'London_eye/254819.jpg',
#  'London_eye/255070.jpg',
#  'London_eye/255084.jpg',
#  'London_eye/255085.jpg',
#  'London_eye/255106.jpg',
#  'London_eye/255107.jpg',
#  'London_eye/255108.jpg',
#  'London_eye/255179.jpg',
#  'London_eye/255460.jpg',
#  'London_eye/25564.jpg',
#  'London_eye/255685.jpg',
#  'London_eye/255690.jpg',
#  'London_eye/256049.jpg',
#  'London_eye/256354.jpg',
#  'London_eye/256669.jpg',
#  'London_eye/257630.jpg',
#  'London_eye/257633.jpg',
#  'London_eye/257696.jpg',
#  'London_eye/257710.jpg',
#  'London_eye/258841.jpg',
#  'London_eye/259869.jpg',
#  'London_eye/260026.jpg',
#  'London_eye/260029.jpg',
#  'London_eye/260922.jpg',
#  'London_eye/261264.jpg',
#  'London_eye/262119.jpg',
#  'London_eye/262345.jpg',
#  'London_eye/262725.jpg',
#  'London_eye/263252.jpg',
#  'London_eye/263415.jpg',
#  'London_eye/263966.jpg',
#  'London_eye/264040.jpg',
#  'London_eye/264126.jpg',
#  'London_eye/264297.jpg',
#  'London_eye/264463.jpg',
#  'London_eye/264495.jpg',
#  'London_eye/264714.jpg',
#  'London_eye/264949.jpg',
#  'London_eye/265066.jpg',
#  'London_eye/265155.jpg',
#  'London_eye/265230.jpg',
#  'London_eye/266011.jpg',
#  'London_eye/266053.jpg',
#  'London_eye/266548.jpg',
#  'London_eye/266577.jpg',
#  'London_eye/266760.jpg',
#  'London_eye/267291.jpg',
#  'London_eye/267319.jpg',
#  'London_eye/267341.jpg',
#  'London_eye/267417.jpg',
#  'London_eye/267577.jpg',
#  'London_eye/267884.jpg',
#  'London_eye/268461.jpg',
#  'London_eye/269248.jpg',
#  'London_eye/27030.jpg',
#  'London_eye/270768.jpg',
#  'London_eye/271459.jpg',
#  'London_eye/271684.jpg',
#  'London_eye/272049.jpg',
#  'London_eye/272543.jpg',
#  'London_eye/273078.jpg',
#  'London_eye/273109.jpg',
#  'London_eye/273463.jpg',
#  'London_eye/273589.jpg',
#  'London_eye/273781.jpg',
#  'London_eye/273999.jpg',
#  'London_eye/274373.jpg',
#  'London_eye/277443.jpg',
#  'London_eye/277938.jpg',
#  'London_eye/278413.jpg',
#  'London_eye/279440.jpg',
#  'London_eye/280228.jpg',
#  'London_eye/280229.jpg',
#  'London_eye/280903.jpg',
#  'London_eye/282410.jpg',
#  'London_eye/282564.jpg',
#  'London_eye/282624.jpg',
#  'London_eye/283198.jpg',
#  'London_eye/286635.jpg',
#  'London_eye/286637.jpg',
#  'London_eye/287968.jpg',
#  'London_eye/290214.jpg',
#  'London_eye/290237.jpg',
#  'London_eye/293047.jpg',
#  'London_eye/294173.jpg',
#  'London_eye/294668.jpg',
#  'London_eye/294684.jpg',
#  'London_eye/294833.jpg',
#  'London_eye/295319.jpg',
#  'London_eye/295726.jpg',
#  'London_eye/295816.jpg',
#  'London_eye/296518.jpg',
#  'London_eye/297094.jpg',
#  'London_eye/297496.jpg',
#  'London_eye/298861.jpg',
#  'London_eye/300113.jpg',
#  'London_eye/300510.jpg',
#  'London_eye/30061.jpg',
#  'London_eye/303529.jpg',
#  'London_eye/303532.jpg',
#  'London_eye/303534.jpg',
#  'London_eye/304480.jpg',
#  'London_eye/307458.jpg',
#  'London_eye/309324.jpg',
#  'London_eye/312981.jpg',
#  'London_eye/313314.jpg',
#  'London_eye/314011.jpg',
#  'London_eye/316883.jpg',
#  'London_eye/320094.jpg',
#  'London_eye/320456.jpg',
#  'London_eye/321068.jpg',
#  'London_eye/321529.jpg',
#  'London_eye/321831.jpg',
#  'London_eye/331124.jpg',
#  'London_eye/332392.jpg',
#  'London_eye/338766.jpg',
#  'London_eye/339111.jpg',
#  'London_eye/339125.jpg',
#  'London_eye/340648.jpg',
#  'London_eye/342359.jpg',
#  'London_eye/346648.jpg',
#  'London_eye/34862.jpg',
#  'London_eye/352123.jpg',
#  'London_eye/353098.jpg',
#  'London_eye/354206.jpg',
#  'London_eye/354236.jpg',
#  'London_eye/354430.jpg',
#  'London_eye/355403.jpg',
#  'London_eye/355441.jpg',
#  'London_eye/355512.jpg',
#  'London_eye/355703.jpg',
#  'London_eye/356836.jpg',
#  'London_eye/357048.jpg',
#  'London_eye/357365.jpg',
#  'London_eye/357384.jpg',
#  'London_eye/357557.jpg',
#  'London_eye/357635.jpg',
#  'London_eye/358037.jpg',
#  'London_eye/359360.jpg',
#  'London_eye/359412.jpg',
#  'London_eye/359802.jpg',
#  'London_eye/359901.jpg',
#  'London_eye/360480.jpg',
#  'London_eye/36050.jpg',
#  'London_eye/360688.jpg',
#  'London_eye/360746.jpg',
#  'London_eye/360964.jpg',
#  'London_eye/361485.jpg',
#  'London_eye/361491.jpg',
#  'London_eye/361754.jpg',
#  'London_eye/361755.jpg',
#  'London_eye/363234.jpg',
#  'London_eye/363985.jpg',
#  'London_eye/364496.jpg',
#  'London_eye/365368.jpg',
#  'London_eye/365580.jpg',
#  'London_eye/365859.jpg',
#  'London_eye/366193.jpg',
#  'London_eye/366328.jpg',
#  'London_eye/366593.jpg',
#  'London_eye/366597.jpg',
#  'London_eye/367514.jpg',
#  'London_eye/367663.jpg',
#  'London_eye/368551.jpg',
#  'London_eye/369221.jpg',
#  'London_eye/369694.jpg',
#  'London_eye/369727.jpg',
#  'London_eye/369728.jpg',
#  'London_eye/369752.jpg',
#  'London_eye/369793.jpg',
#  'London_eye/369981.jpg',
#  'London_eye/372269.jpg',
#  'London_eye/372435.jpg',
#  'London_eye/373185.jpg',
#  'London_eye/373409.jpg',
#  'London_eye/373704.jpg',
#  'London_eye/374083.jpg',
#  'London_eye/374157.jpg',
#  'London_eye/375981.jpg',
#  'London_eye/376840.jpg',
#  'London_eye/377027.jpg',
#  'London_eye/378695.jpg',
#  'London_eye/378991.jpg',
#  'London_eye/379142.jpg',
#  'London_eye/379336.jpg',
#  'London_eye/379554.jpg',
#  'London_eye/379753.jpg',
#  'London_eye/379831.jpg',
#  'London_eye/379890.jpg',
#  'London_eye/380016.jpg',
#  'London_eye/380087.jpg',
#  'London_eye/380290.jpg',
#  'London_eye/380303.jpg',
#  'London_eye/380611.jpg',
#  'London_eye/380772.jpg',
#  'London_eye/381149.jpg',
#  'London_eye/381592.jpg',
#  'London_eye/381862.jpg',
#  'London_eye/382125.jpg',
#  'London_eye/382368.jpg',
#  'London_eye/382499.jpg',
#  'London_eye/382696.jpg',
#  'London_eye/382713.jpg',
#  'London_eye/382817.jpg',
#  'London_eye/383226.jpg',
#  'London_eye/383480.jpg',
#  'London_eye/383485.jpg',
#  'London_eye/383774.jpg',
#  'London_eye/384029.jpg',
#  'London_eye/384131.jpg',
#  'London_eye/384446.jpg',
#  'London_eye/384451.jpg',
#  'London_eye/384466.jpg',
#  'London_eye/384754.jpg',
#  'London_eye/384982.jpg',
#  'London_eye/385386.jpg',
#  'London_eye/385968.jpg',
#  'London_eye/386303.jpg',
#  'London_eye/386352.jpg',
#  'London_eye/386511.jpg',
#  'London_eye/387349.jpg',
#  'London_eye/387385.jpg',
#  'London_eye/387552.jpg',
#  'London_eye/387771.jpg',
#  'London_eye/387973.jpg',
#  'London_eye/388013.jpg',
#  'London_eye/388671.jpg',
#  'London_eye/388718.jpg',
#  'London_eye/388725.jpg',
#  'London_eye/389016.jpg',
#  'London_eye/389181.jpg',
#  'London_eye/389197.jpg',
#  'London_eye/389450.jpg',
#  'London_eye/389595.jpg',
#  'London_eye/390771.jpg',
#  'London_eye/391148.jpg',
#  'London_eye/391574.jpg',
#  'London_eye/391637.jpg',
#  'London_eye/391640.jpg',
#  'London_eye/392240.jpg',
#  'London_eye/392248.jpg',
#  'London_eye/392252.jpg',
#  'London_eye/393683.jpg',
#  'London_eye/393715.jpg',
#  'London_eye/393963.jpg',
#  'London_eye/394705.jpg',
#  'London_eye/395300.jpg',
#  'London_eye/395388.jpg',
#  'London_eye/395912.jpg',
#  'London_eye/396759.jpg',
#  'London_eye/397020.jpg',
#  'London_eye/397021.jpg',
#  'London_eye/397121.jpg',
#  'London_eye/398334.jpg',
#  'London_eye/399937.jpg',
#  'London_eye/400159.jpg',
#  'London_eye/400886.jpg',
#  'London_eye/401125.jpg',
#  'London_eye/401241.jpg',
#  'London_eye/402071.jpg',
#  'London_eye/402830.jpg',
#  'London_eye/403080.jpg',
#  'London_eye/404031.jpg',
#  'London_eye/405058.jpg',
#  'London_eye/405630.jpg',
#  'London_eye/406096.jpg',
#  'London_eye/408270.jpg',
#  'London_eye/409301.jpg',
#  'London_eye/411088.jpg',
#  'London_eye/411148.jpg',
#  'London_eye/411377.jpg',
#  'London_eye/411410.jpg',
#  'London_eye/411431.jpg',
#  'London_eye/412173.jpg',
#  'London_eye/413681.jpg',
#  'London_eye/414060.jpg',
#  'London_eye/414992.jpg',
#  'London_eye/415870.jpg',
#  'London_eye/416044.jpg',
#  'London_eye/416535.jpg',
#  'London_eye/417065.jpg',
#  'London_eye/417383.jpg',
#  'London_eye/417427.jpg',
#  'London_eye/418870.jpg',
#  'London_eye/421197.jpg',
#  'London_eye/438035.jpg',
#  'London_eye/440231.jpg',
#  'London_eye/443892.jpg',
#  'London_eye/450865.jpg',
#  'London_eye/453770.jpg',
#  'London_eye/454164.jpg',
#  'London_eye/454181.jpg',
#  'London_eye/459122.jpg',
#  'London_eye/464686.jpg',
#  'London_eye/464697.jpg',
#  'London_eye/464733.jpg',
#  'London_eye/467190.jpg',
#  'London_eye/470984.jpg',
#  'London_eye/473609.jpg',
#  'London_eye/475048.jpg',
#  'London_eye/477739.jpg',
#  'London_eye/480417.jpg',
#  'London_eye/480742.jpg',
#  'London_eye/480746.jpg',
#  'London_eye/485975.jpg',
#  'London_eye/486458.jpg',
#  'London_eye/486459.jpg',
#  'London_eye/486620.jpg',
#  'London_eye/487486.jpg',
#  'London_eye/488236.jpg',
#  'London_eye/488242.jpg',
#  'London_eye/488461.jpg',
#  'London_eye/494481.jpg',
#  'London_eye/498351.jpg',
#  'London_eye/500274.jpg',
#  'London_eye/500312.jpg',
#  'London_eye/500870.jpg',
#  'London_eye/500871.jpg',
#  'London_eye/500982.jpg',
#  'London_eye/501839.jpg',
#  'London_eye/502169.jpg',
#  'London_eye/504987.jpg',
#  'London_eye/506595.jpg',
#  'London_eye/506948.jpg',
#  'London_eye/508633.jpg',
#  'London_eye/510033.jpg',
#  'London_eye/510507.jpg',
#  'London_eye/511597.jpg',
#  'London_eye/512428.jpg',
#  'London_eye/513849.jpg',
#  'London_eye/515283.jpg',
#  'London_eye/517500.jpg',
#  'London_eye/534805.jpg',
#  'London_eye/535054.jpg',
#  'London_eye/536444.jpg',
#  'London_eye/536520.jpg',
#  'London_eye/536522.jpg',
#  'London_eye/539829.jpg',
#  'London_eye/540703.jpg',
#  'London_eye/542210.jpg',
#  'London_eye/542223.jpg',
#  'London_eye/544333.jpg',
#  'London_eye/546440.jpg',
#  'London_eye/549298.jpg',
#  'London_eye/554872.jpg',
#  'London_eye/559275.jpg',
#  'London_eye/562304.jpg',
#  'London_eye/562312.jpg',
#  'London_eye/562320.jpg',
#  'London_eye/567972.jpg',
#  'London_eye/571868.jpg',
#  'London_eye/5734.jpg',
#  'London_eye/575889.jpg',
#  'London_eye/577597.jpg',
#  'London_eye/581066.jpg',
#  'London_eye/582609.jpg',
#  'London_eye/583047.jpg',
#  'London_eye/586025.jpg',
#  'London_eye/586241.jpg',
#  'London_eye/587302.jpg',
#  'London_eye/587634.jpg',
#  'London_eye/587743.jpg',
#  'London_eye/592049.jpg',
#  'London_eye/595793.jpg',
#  'London_eye/595796.jpg',
#  'London_eye/59867.jpg',
#  'London_eye/599923.jpg',
#  'London_eye/605296.jpg',
#  'London_eye/605325.jpg',
#  'London_eye/606961.jpg',
#  'London_eye/608477.jpg',
#  'London_eye/612016.jpg',
#  'London_eye/612851.jpg',
#  'London_eye/613100.jpg',
#  'London_eye/613485.jpg',
#  'London_eye/613552.jpg',
#  'London_eye/613830.jpg',
#  'London_eye/614216.jpg',
#  'London_eye/614926.jpg',
#  'London_eye/616709.jpg',
#  'London_eye/618916.jpg',
#  'London_eye/619110.jpg',
#  'London_eye/619676.jpg',
#  'London_eye/624883.jpg',
#  'London_eye/628183.jpg',
#  'London_eye/629654.jpg',
#  'London_eye/631470.jpg',
#  'London_eye/635410.jpg',
#  'London_eye/635483.jpg',
#  'London_eye/636016.jpg',
#  'London_eye/636063.jpg',
#  'London_eye/636359.jpg',
#  'London_eye/639294.jpg',
#  'London_eye/640339.jpg',
#  'London_eye/640470.jpg',
#  'London_eye/640911.jpg',
#  'London_eye/644045.jpg',
#  'London_eye/647118.jpg',
#  'London_eye/648071.jpg',
#  'London_eye/648775.jpg',
#  'London_eye/650654.jpg',
#  'London_eye/650740.jpg',
#  'London_eye/651755.jpg',
#  'London_eye/651758.jpg',
#  'London_eye/652157.jpg',
#  'London_eye/653531.jpg',
#  'London_eye/653535.jpg',
#  'London_eye/653721.jpg',
#  'London_eye/653731.jpg',
#  'London_eye/653741.jpg',
#  'London_eye/654180.jpg',
#  'London_eye/654277.jpg',
#  'London_eye/655545.jpg',
#  'London_eye/655546.jpg',
#  'London_eye/655547.jpg',
#  'London_eye/655593.jpg',
#  'London_eye/656396.jpg',
#  'London_eye/656510.jpg',
#  'London_eye/657043.jpg',
#  'London_eye/657044.jpg',
#  'London_eye/657045.jpg',
#  'London_eye/657301.jpg',
#  'London_eye/657618.jpg',
#  'London_eye/658397.jpg',
#  'London_eye/658895.jpg',
#  'London_eye/660445.jpg',
#  'London_eye/661471.jpg',
#  'London_eye/661820.jpg',
#  'London_eye/662504.jpg',
#  'London_eye/6626.jpg',
#  'London_eye/663727.jpg',
#  'London_eye/665668.jpg',
#  'London_eye/666152.jpg',
#  'London_eye/666400.jpg',
#  'London_eye/666797.jpg',
#  'London_eye/667004.jpg',
#  'London_eye/667082.jpg',
#  'London_eye/667090.jpg',
#  'London_eye/667095.jpg',
#  'London_eye/668149.jpg',
#  'London_eye/669021.jpg',
#  'London_eye/669395.jpg',
#  'London_eye/673857.jpg',
#  'London_eye/674138.jpg',
#  'London_eye/674179.jpg',
#  'London_eye/676267.jpg',
#  'London_eye/677263.jpg',
#  'London_eye/678106.jpg',
#  'London_eye/679342.jpg',
#  'London_eye/681299.jpg',
#  'London_eye/681382.jpg',
#  'London_eye/682637.jpg',
#  'London_eye/682766.jpg',
#  'London_eye/683751.jpg',
#  'London_eye/683752.jpg',
#  'London_eye/686082.jpg',
#  'London_eye/688138.jpg',
#  'London_eye/688144.jpg',
#  'London_eye/689032.jpg',
#  'London_eye/690155.jpg',
#  'London_eye/691681.jpg',
#  'London_eye/692887.jpg',
#  'London_eye/693487.jpg',
#  'London_eye/693489.jpg',
#  'London_eye/693490.jpg',
#  'London_eye/694214.jpg',
#  'London_eye/695028.jpg',
#  'London_eye/695987.jpg',
#  'London_eye/698209.jpg',
#  'London_eye/699350.jpg',
#  'London_eye/699749.jpg',
#  'London_eye/700828.jpg',
#  'London_eye/701250.jpg',
#  'London_eye/701376.jpg',
#  'London_eye/703231.jpg',
#  'London_eye/703257.jpg',
#  'London_eye/703331.jpg',
#  'London_eye/703345.jpg',
#  'London_eye/703542.jpg',
#  'London_eye/704090.jpg',
#  'London_eye/704111.jpg',
#  'London_eye/704343.jpg',
#  'London_eye/707616.jpg',
#  'London_eye/708983.jpg',
#  'London_eye/709823.jpg',
#  'London_eye/710732.jpg',
#  'London_eye/711530.jpg',
#  'London_eye/711546.jpg',
#  'London_eye/712146.jpg',
#  'London_eye/713501.jpg',
#  'London_eye/714231.jpg',
#  'London_eye/714381.jpg',
#  'London_eye/714386.jpg',
#  'London_eye/715332.jpg',
#  'London_eye/715597.jpg',
#  'London_eye/717434.jpg',
#  'London_eye/717440.jpg',
#  'London_eye/718185.jpg',
#  'London_eye/718241.jpg',
#  'London_eye/718851.jpg',
#  'London_eye/719402.jpg',
#  'London_eye/719534.jpg',
#  'London_eye/719593.jpg',
#  'London_eye/720941.jpg',
#  'London_eye/720942.jpg',
#  'London_eye/720943.jpg',
#  'London_eye/720945.jpg',
#  'London_eye/720947.jpg',
#  'London_eye/725026.jpg',
#  'London_eye/725847.jpg',
#  'London_eye/726411.jpg',
#  'London_eye/727129.jpg',
#  'London_eye/727130.jpg',
#  'London_eye/729163.jpg',
#  'London_eye/73034.jpg',
#  'London_eye/730900.jpg',
#  'London_eye/734017.jpg',
#  'London_eye/734025.jpg',
#  'London_eye/734378.jpg',
#  'London_eye/735602.jpg',
#  'London_eye/735624.jpg',
#  'London_eye/737883.jpg',
#  'London_eye/737884.jpg',
#  'London_eye/738104.jpg',
#  'London_eye/738978.jpg',
#  'London_eye/740367.jpg',
#  'London_eye/741645.jpg',
#  'London_eye/741679.jpg',
#  'London_eye/741753.jpg',
#  'London_eye/742605.jpg',
#  'London_eye/742606.jpg',
#  'London_eye/742997.jpg',
#  'London_eye/743472.jpg',
#  'London_eye/744466.jpg',
#  'London_eye/745027.jpg',
#  'London_eye/745094.jpg',
#  'London_eye/74767.jpg',
#  'London_eye/747.jpg',
#  'London_eye/748950.jpg',
#  'London_eye/74951.jpg',
#  'London_eye/750180.jpg',
#  'London_eye/753999.jpg',
#  'London_eye/755199.jpg',
#  'London_eye/757024.jpg',
#  'London_eye/757029.jpg',
#  'London_eye/757310.jpg',
#  'London_eye/759464.jpg',
#  'London_eye/761438.jpg',
#  'London_eye/762444.jpg',
#  'London_eye/763614.jpg',
#  'London_eye/763770.jpg',
#  'London_eye/763771.jpg',
#  'London_eye/763933.jpg',
#  'London_eye/763934.jpg',
#  'London_eye/763955.jpg',
#  'London_eye/764044.jpg',
#  'London_eye/764471.jpg',
#  'London_eye/764701.jpg',
#  'London_eye/766378.jpg',
#  'London_eye/76731.jpg',
#  'London_eye/767366.jpg',
#  'London_eye/768646.jpg',
#  'London_eye/769117.jpg',
#  'London_eye/769118.jpg',
#  'London_eye/769119.jpg',
#  'London_eye/771474.jpg',
#  'London_eye/774605.jpg',
#  'London_eye/775932.jpg',
#  'London_eye/776821.jpg',
#  'London_eye/777463.jpg',
#  'London_eye/777469.jpg',
#  'London_eye/777506.jpg',
#  'London_eye/779577.jpg',
#  'London_eye/779579.jpg',
#  'London_eye/779583.jpg',
#  'London_eye/779594.jpg',
#  'London_eye/779599.jpg',
#  'London_eye/78161.jpg',
#  'London_eye/783277.jpg',
#  'London_eye/783349.jpg',
#  'London_eye/783451.jpg',
#  'London_eye/783456.jpg',
#  'London_eye/785627.jpg',
#  'London_eye/785727.jpg',
#  'London_eye/786597.jpg',
#  'London_eye/786608.jpg',
#  'London_eye/786609.jpg',
#  'London_eye/78661.jpg',
#  'London_eye/787289.jpg',
#  'London_eye/787290.jpg',
#  'London_eye/787291.jpg',
#  'London_eye/788679.jpg',
#  'London_eye/789570.jpg',
#  'London_eye/789943.jpg',
#  'London_eye/791027.jpg',
#  'London_eye/793541.jpg',
#  'London_eye/793547.jpg',
#  'London_eye/793688.jpg',
#  'London_eye/794250.jpg',
#  'London_eye/794624.jpg',
#  'London_eye/795199.jpg',
#  'London_eye/795530.jpg',
#  'London_eye/795608.jpg',
#  'London_eye/796301.jpg',
#  'London_eye/796348.jpg',
#  'London_eye/796665.jpg',
#  'London_eye/796683.jpg',
#  'London_eye/797296.jpg',
#  'London_eye/797853.jpg',
#  'London_eye/798294.jpg',
#  'London_eye/803922.jpg',
#  'London_eye/804743.jpg',
#  'London_eye/804825.jpg',
#  'London_eye/821322.jpg',
#  'London_eye/826548.jpg',
#  'London_eye/843496.jpg',
#  'London_eye/847506.jpg',
#  'London_eye/848012.jpg',
#  'London_eye/859319.jpg',
#  'London_eye/860465.jpg',
#  'London_eye/861802.jpg',
#  'London_eye/864119.jpg',
#  'London_eye/8649.jpg',
#  'London_eye/8650.jpg',
#  'London_eye/865679.jpg',
#  'London_eye/865680.jpg',
#  'London_eye/869564.jpg',
#  'London_eye/879239.jpg',
#  'London_eye/892315.jpg',
#  'London_eye/892425.jpg',
#  'London_eye/894155.jpg',
#  'London_eye/895205.jpg',
#  'London_eye/895911.jpg',
#  'London_eye/904719.jpg',
#  'London_eye/907005.jpg',
#  'London_eye/914624.jpg',
#  'London_eye/914851.jpg',
#  'London_eye/915026.jpg',
#  'London_eye/915101.jpg',
#  'London_eye/915102.jpg',
#  'London_eye/915111.jpg',
#  'London_eye/915116.jpg',
#  'London_eye/915127.jpg',
#  'London_eye/915333.jpg',
#  'London_eye/917723.jpg',
#  'London_eye/919732.jpg',
#  'London_eye/926250.jpg',
#  'London_eye/928326.jpg',
#  'London_eye/929506.jpg',
#  'London_eye/93008.jpg',
#  'London_eye/931447.jpg',
#  'London_eye/933273.jpg',
#  'London_eye/933888.jpg',
#  'London_eye/935736.jpg',
#  'London_eye/942370.jpg',
#  'London_eye/942853.jpg',
#  'London_eye/943208.jpg',
#  'London_eye/947406.jpg',
#  'London_eye/947417.jpg',
#  'London_eye/949464.jpg',
#  'London_eye/949477.jpg',
#  'London_eye/952051.jpg',
#  'London_eye/952724.jpg',
#  'London_eye/955261.jpg',
#  'London_eye/957913.jpg',
#  'London_eye/962044.jpg',
#  'London_eye/962163.jpg',
#  'London_eye/963559.jpg',
#  'London_eye/965431.jpg',
#  'London_eye/966898.jpg',
#  'London_eye/973560.jpg',
#  'London_eye/975779.jpg',
#  'London_eye/989408.jpg',
#  'London_eye/99541.jpg',
#  'London_eye/997207.jpg',
#  'moon/101719.jpg',
#  'moon/1020889.jpg',
#  'moon/1022437.jpg',
#  'moon/102256.jpg',
#  'moon/102389.jpg',
#  'moon/1060295.jpg',
#  'moon/106244.jpg',
#  'moon/106623.jpg',
#  'moon/106747.jpg',
#  'moon/106795.jpg',
#  'moon/107015.jpg',
#  'moon/107183.jpg',
#  'moon/107186.jpg',
#  'moon/107320.jpg',
#  'moon/107675.jpg',
#  'moon/108481.jpg',
#  'moon/109043.jpg',
#  'moon/109975.jpg',
#  'moon/110296.jpg',
#  'moon/110477.jpg',
#  'moon/110480.jpg',
#  'moon/110876.jpg',
#  'moon/110898.jpg',
#  'moon/110899.jpg',
#  'moon/110985.jpg',
#  'moon/111036.jpg',
#  'moon/111251.jpg',
#  'moon/111495.jpg',
#  'moon/111510.jpg',
#  'moon/111833.jpg',
#  'moon/111977.jpg',
#  'moon/112175.jpg',
#  'moon/112177.jpg',
#  'moon/112181.jpg',
#  'moon/112342.jpg',
#  'moon/112347.jpg',
#  'moon/112380.jpg',
#  'moon/112383.jpg',
#  'moon/112385.jpg',
#  'moon/112625.jpg',
#  'moon/112639.jpg',
#  'moon/112778.jpg',
#  'moon/114267.jpg',
#  'moon/114321.jpg',
#  'moon/115143.jpg',
#  'moon/115372.jpg',
#  'moon/115440.jpg',
#  'moon/115774.jpg',
#  'moon/116139.jpg',
#  'moon/116421.jpg',
#  'moon/116444.jpg',
#  'moon/116551.jpg',
#  'moon/117203.jpg',
#  'moon/117971.jpg',
#  'moon/117972.jpg',
#  'moon/119329.jpg',
#  'moon/119901.jpg',
#  'moon/120648.jpg',
#  'moon/120741.jpg',
#  'moon/122359.jpg',
#  'moon/123962.jpg',
#  'moon/124446.jpg',
#  'moon/124742.jpg',
#  'moon/125336.jpg',
#  'moon/125367.jpg',
#  'moon/125779.jpg',
#  'moon/126297.jpg',
#  'moon/126788.jpg',
#  'moon/126884.jpg',
#  'moon/126950.jpg',
#  'moon/126955.jpg',
#  'moon/126967.jpg',
#  'moon/127145.jpg',
#  'moon/127267.jpg',
#  'moon/127780.jpg',
#  'moon/128016.jpg',
#  'moon/128539.jpg',
#  'moon/128622.jpg',
#  'moon/128991.jpg',
#  'moon/129367.jpg',
#  'moon/129469.jpg',
#  'moon/129500.jpg',
#  'moon/129510.jpg',
#  'moon/129526.jpg',
#  'moon/129636.jpg',
#  'moon/129674.jpg',
#  'moon/129744.jpg',
#  'moon/129772.jpg',
#  'moon/129784.jpg',
#  'moon/129802.jpg',
#  'moon/129808.jpg',
#  'moon/130378.jpg',
#  'moon/130419.jpg',
#  'moon/130435.jpg',
#  'moon/130787.jpg',
#  'moon/130880.jpg',
#  'moon/131159.jpg',
#  'moon/131295.jpg',
#  'moon/131811.jpg',
#  'moon/131888.jpg',
#  'moon/132315.jpg',
#  'moon/132441.jpg',
#  'moon/132683.jpg',
#  'moon/132752.jpg',
#  'moon/133329.jpg',
#  'moon/133370.jpg',
#  'moon/133420.jpg',
#  'moon/133564.jpg',
#  'moon/133582.jpg',
#  'moon/133583.jpg',
#  ...]

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib

get_ipython().magic(u'matplotlib inline')
matplotlib.rcParams["savefig.dpi"] = 400 # to get high resolution

# %% [markdown]
# ##Sample canny edge detection

# %%
img = cv2.imread(os.path.join(os.path.dirname(notebook_path),'software/Flickr15K/images/Taj_Mahal/1024263.jpg'))
edges = cv2.Canny(img,150,200)
edges = cv2.cvtColor(edges,cv2.COLOR_GRAY2RGB)

# %% [markdown]
# ## Feature extraction using VGG

# %%
from os import listdir
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Input, Subtract, Lambda
from pickle import dump
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.models import Model
import numpy as np

def extract_features(directory):
  model = VGG16()
  model = Model(inputs=model.inputs, outputs=model.layers[-3].output)
  features=dict()
  count=0
  res=[]
  
  for name in imageName:
    count+=1
    filename = directory + '/' + name
    image = cv2.imread(filename)
    
    image = cv2.Canny(image,150,200)
    image = cv2.resize(image, (224,224))
    image = cv2.cvtColor(image,cv2.COLOR_GRAY2RGB)
    image = np.array(image)
    image = image.reshape((1,image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    feature = model.predict(image, verbose=0)
    image_id = name.split('.')[0]
    features[image_id] = feature
    if count%100==0:
      print('>%s' % name)
    
  return features

directory = '/content/drive/My Drive/IR/Flickr15K/images'
features = extract_features(directory)
print('Extracted Features: %d' % len(features))
dump(features, open('/content/drive/My Drive/IR/VGG16.pkl', 'wb'))
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_3[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None
# >London_eye/141967.jpg
# >London_eye/253510.jpg
# >London_eye/294173.jpg
# >London_eye/379336.jpg
# >London_eye/421197.jpg
# >London_eye/628183.jpg
# >London_eye/709823.jpg
# >London_eye/786597.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9d16fafd8529> in <module>
#      55 # extract features from all images
#      56 directory = '/content/drive/My Drive/IR/Flickr15K/images'
# ---> 57 features = extract_features(directory)
#      58 print('Extracted Features: %d' % len(features))
#      59 # save to file
#
# <ipython-input-19-9d16fafd8529> in extract_features(directory)
#      41     image = preprocess_input(image)
#      42     # get features
# ---> 43     feature = model.predict(image, verbose=0)
#      44     # get image id
#      45     # print(np.shape(feature))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2031           for step in data_handler.steps():
#    2032             callbacks.on_predict_batch_begin(step)
# -> 2033             tmp_batch_outputs = self.predict_function(iterator)
#    2034             if data_handler.should_sync:
#    2035               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
features

# %% [markdown]
# ## Loading Feature vectors

# %%
import pickle
file=open(os.path.join(os.path.dirname(notebook_path),'/software/VGG16.pkl'),'rb')
feature_real=pickle.load(file)
file.close()

file=open(os.path.join(os.path.dirname(notebook_path),'/software/sketch_features/VGG16.pkl'),'rb')
feature_sketch=pickle.load(file)
file.close()

# %%
import numpy as np
np.shape(feature_real['airplane/104249'][0])
# Out:
# (7, 7, 2048)

# %% [markdown]
# ##Cosine similarity ranking

# %%
from sklearn.metrics.pairwise import cosine_similarity
def findRanking(feature_real,query):
  ranking=[]
  v2=query 
  for filename in feature_real:
    v1=feature_real[filename] 
    
    ranking.append([filename,cosine_similarity(v1,v2)])
  
  ranking=sorted(ranking, key=lambda x: x[1], reverse = True)
  return ranking

# %% [markdown]
# generating ranking for every query

# %%
result={}
count=0
for filename in feature_sketch:
  count+=1
  result[filename]=findRanking(feature_real,feature_sketch[filename])
  if count%10==0:
    print(filename," ",count)
# Out:
# 1/10   10
# 1/20   20
# 1/30   30
# 2/7   40
# 2/17   50
# 2/27   60
# 3/4   70
# 3/14   80
# 3/24   90
# 4/1   100
# 4/11   110
# 4/21   120
# 4/31   130
# 5/8   140
# 5/18   150
# 5/28   160
# 6/5   170
# 6/15   180
# 6/25   190
# 7/2   200
# 7/12   210
# 7/22   220
# 7/32   230
# 8/9   240
# 8/19   250
# 8/29   260
# 9/6   270
# 9/16   280
# 9/26   290
# 10/3   300
# 10/13   310
# 10/23   320
# 10/33   330

# %%
real_relevant_image = {}
for i in range(1, 34):
  real_relevant_image[i] = []
file = open(os.path.join(os.path.dirname(notebook_path),"/software/Flickr15K/list_images.txt"), "r")
title_list = []
for line in file.readlines():
    line = line.strip('\n').split(" ")
    number = int(line[0])
    name = line[1].split("/")[0]
    if name not in real_relevant_image[number]:
      real_relevant_image[number].append(name)
file.close()

# %%
real_relevant_image[20]
# Out:
# ['heart_shape']

# %% [markdown]
# Loading Ranking which was dumped before

# %%
import pickle
file=open(os.path.join(os.path.dirname(notebook_path),'/software/VGG16List.pkl'),'rb')
ranking_vgg=pickle.load(file)
file.close()

# %% [markdown]
# # SBIR MAP

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
real_relevant_image = {}
title_list = {}
for i in range(1, 34):
  real_relevant_image[i] = []
  title_list[i] = []
file = open(os.path.join(os.path.dirname(notebook_path),"/software/Flickr15K/list_images.txt"), "r")

for line in file.readlines():
    line = line.strip('\n').split(" ")
    number = int(line[0])
    name = line[1].split(".")[0]
    if name not in real_relevant_image[number]:
      real_relevant_image[number].append(name)
    if name.split('/')[0] not in title_list[number]:
      title_list[number].append(name.split('/')[0])
file.close()

# %%
sketch_relevent = {}
for i in range(1, 34):
  sketch_relevent[i] = 0
file = open(os.path.join(os.path.dirname(notebook_path),"/software/Flickr15K/list_images.txt"), "r")
title_list = []
for line in file.readlines():
    line = line.strip('\n').split(" ")
    number = int(line[0])
    name = line[1].split("/")[0]
    sketch_relevent[number]+=1
file.close()

# %%
real_relevant_image[1]
# Out:
# ['fire_balloon/110181',
#  'fire_balloon/129097',
#  'fire_balloon/13794',
#  'fire_balloon/138163',
#  'fire_balloon/142476',
#  'fire_balloon/142850',
#  'fire_balloon/142984',
#  'fire_balloon/143028',
#  'fire_balloon/356485',
#  'fire_balloon/356488',
#  'fire_balloon/356491',
#  'fire_balloon/356498',
#  'fire_balloon/356557',
#  'fire_balloon/366639',
#  'fire_balloon/384541',
#  'fire_balloon/390060',
#  'fire_balloon/551831',
#  'fire_balloon/551835',
#  'fire_balloon/566962',
#  'fire_balloon/60385',
#  'fire_balloon/60388',
#  'fire_balloon/73852',
#  'fire_balloon/73863',
#  'fire_balloon/81386',
#  'fire_balloon/81393',
#  'fire_balloon/90415',
#  'fire_balloon/917248',
#  'fire_balloon/917249',
#  'fire_balloon/917254',
#  'fire_balloon/947521',
#  'fire_balloon/96346',
#  'fire_balloon/96384',
#  'fire_balloon/96539',
#  'fire_balloon/97479',
#  'fire_balloon/99016',
#  'fire_balloon/990953',
#  'London_eye/1001395',
#  'London_eye/100246',
#  'London_eye/1004885',
#  'London_eye/1006701',
#  'London_eye/1006751',
#  'London_eye/1006928',
#  'London_eye/1008297',
#  'London_eye/1009216',
#  'London_eye/1009572',
#  'London_eye/1009886',
#  'London_eye/101094',
#  'London_eye/101097',
#  'London_eye/1011324',
#  'London_eye/1011369',
#  'London_eye/1012301',
#  'London_eye/1022403',
#  'London_eye/1022711',
#  'London_eye/1022871',
#  'London_eye/1023023',
#  'London_eye/1023042',
#  'London_eye/1023431',
#  'London_eye/1024164',
#  'London_eye/1024602',
#  'London_eye/1025018',
#  'London_eye/1028033',
#  'London_eye/1029967',
#  'London_eye/1030020',
#  'London_eye/1030065',
#  'London_eye/1030067',
#  'London_eye/1030988',
#  'London_eye/1031168',
#  'London_eye/1032669',
#  'London_eye/1033820',
#  'London_eye/1034356',
#  'London_eye/1038816',
#  'London_eye/1042354',
#  'London_eye/1043308',
#  'London_eye/1047159',
#  'London_eye/1048038',
#  'London_eye/1048040',
#  'London_eye/1048047',
#  'London_eye/1050380',
#  'London_eye/105068',
#  'London_eye/105069',
#  'London_eye/1051898',
#  'London_eye/1052139',
#  'London_eye/1053149',
#  'London_eye/1053541',
#  'London_eye/1056844',
#  'London_eye/1056958',
#  'London_eye/1057716',
#  'London_eye/1059926',
#  'London_eye/1060120',
#  'London_eye/1061697',
#  'London_eye/1061962',
#  'London_eye/1061980',
#  'London_eye/1063974',
#  'London_eye/10660',
#  'London_eye/106671',
#  'London_eye/10950',
#  'London_eye/1102',
#  'London_eye/113693',
#  'London_eye/141502',
#  'London_eye/141967',
#  'London_eye/14455',
#  'London_eye/148037',
#  'London_eye/149256',
#  'London_eye/15311',
#  'London_eye/164071',
#  'London_eye/16676',
#  'London_eye/167629',
#  'London_eye/168541',
#  'London_eye/168545',
#  'London_eye/168638',
#  'London_eye/168657',
#  'London_eye/168980',
#  'London_eye/170451',
#  'London_eye/173723',
#  'London_eye/173728',
#  'London_eye/173729',
#  'London_eye/174599',
#  'London_eye/174783',
#  'London_eye/174856',
#  'London_eye/175391',
#  'London_eye/175756',
#  'London_eye/175759',
#  'London_eye/176384',
#  'London_eye/177755',
#  'London_eye/177821',
#  'London_eye/177822',
#  'London_eye/177829',
#  'London_eye/178292',
#  'London_eye/180045',
#  'London_eye/180515',
#  'London_eye/180637',
#  'London_eye/184678',
#  'London_eye/188372',
#  'London_eye/188796',
#  'London_eye/190254',
#  'London_eye/190797',
#  'London_eye/190799',
#  'London_eye/190922',
#  'London_eye/191655',
#  'London_eye/196761',
#  'London_eye/197127',
#  'London_eye/197654',
#  'London_eye/197686',
#  'London_eye/203431',
#  'London_eye/207776',
#  'London_eye/20882',
#  'London_eye/209481',
#  'London_eye/211317',
#  'London_eye/212376',
#  'London_eye/216059',
#  'London_eye/216425',
#  'London_eye/220385',
#  'London_eye/221433',
#  'London_eye/222714',
#  'London_eye/225724',
#  'London_eye/225864',
#  'London_eye/226938',
#  'London_eye/229704',
#  'London_eye/230149',
#  'London_eye/231134',
#  'London_eye/231852',
#  'London_eye/232593',
#  'London_eye/232594',
#  'London_eye/233308',
#  'London_eye/233423',
#  'London_eye/233580',
#  'London_eye/233755',
#  'London_eye/234401',
#  'London_eye/234405',
#  'London_eye/234407',
#  'London_eye/234514',
#  'London_eye/234800',
#  'London_eye/234945',
#  'London_eye/234946',
#  'London_eye/234948',
#  'London_eye/234951',
#  'London_eye/235346',
#  'London_eye/236882',
#  'London_eye/237186',
#  'London_eye/238319',
#  'London_eye/24027',
#  'London_eye/240848',
#  'London_eye/241661',
#  'London_eye/242717',
#  'London_eye/245296',
#  'London_eye/246631',
#  'London_eye/247027',
#  'London_eye/247451',
#  'London_eye/25002',
#  'London_eye/25007',
#  'London_eye/25078',
#  'London_eye/252025',
#  'London_eye/252068',
#  'London_eye/252542',
#  'London_eye/252851',
#  'London_eye/252927',
#  'London_eye/253405',
#  'London_eye/253506',
#  'London_eye/253507',
#  'London_eye/253510',
#  'London_eye/253511',
#  'London_eye/253512',
#  'London_eye/253631',
#  'London_eye/253632',
#  'London_eye/253806',
#  'London_eye/253808',
#  'London_eye/253809',
#  'London_eye/253810',
#  'London_eye/254794',
#  'London_eye/254795',
#  'London_eye/254796',
#  'London_eye/254808',
#  'London_eye/254809',
#  'London_eye/254817',
#  'London_eye/254818',
#  'London_eye/254819',
#  'London_eye/255070',
#  'London_eye/255084',
#  'London_eye/255085',
#  'London_eye/255106',
#  'London_eye/255107',
#  'London_eye/255108',
#  'London_eye/255179',
#  'London_eye/255460',
#  'London_eye/25564',
#  'London_eye/255685',
#  'London_eye/255690',
#  'London_eye/256049',
#  'London_eye/256354',
#  'London_eye/256669',
#  'London_eye/257630',
#  'London_eye/257633',
#  'London_eye/257696',
#  'London_eye/257710',
#  'London_eye/258841',
#  'London_eye/259869',
#  'London_eye/260026',
#  'London_eye/260029',
#  'London_eye/260922',
#  'London_eye/261264',
#  'London_eye/262119',
#  'London_eye/262345',
#  'London_eye/262725',
#  'London_eye/263252',
#  'London_eye/263415',
#  'London_eye/263966',
#  'London_eye/264040',
#  'London_eye/264126',
#  'London_eye/264297',
#  'London_eye/264463',
#  'London_eye/264495',
#  'London_eye/264714',
#  'London_eye/264949',
#  'London_eye/265066',
#  'London_eye/265155',
#  'London_eye/265230',
#  'London_eye/266011',
#  'London_eye/266053',
#  'London_eye/266548',
#  'London_eye/266577',
#  'London_eye/266760',
#  'London_eye/267291',
#  'London_eye/267319',
#  'London_eye/267341',
#  'London_eye/267417',
#  'London_eye/267577',
#  'London_eye/267884',
#  'London_eye/268461',
#  'London_eye/269248',
#  'London_eye/27030',
#  'London_eye/270768',
#  'London_eye/271459',
#  'London_eye/271684',
#  'London_eye/272049',
#  'London_eye/272543',
#  'London_eye/273078',
#  'London_eye/273109',
#  'London_eye/273463',
#  'London_eye/273589',
#  'London_eye/273781',
#  'London_eye/273999',
#  'London_eye/274373',
#  'London_eye/277443',
#  'London_eye/277938',
#  'London_eye/278413',
#  'London_eye/279440',
#  'London_eye/280228',
#  'London_eye/280229',
#  'London_eye/280903',
#  'London_eye/282410',
#  'London_eye/282564',
#  'London_eye/282624',
#  'London_eye/283198',
#  'London_eye/286635',
#  'London_eye/286637',
#  'London_eye/287968',
#  'London_eye/290214',
#  'London_eye/290237',
#  'London_eye/293047',
#  'London_eye/294173',
#  'London_eye/294668',
#  'London_eye/294684',
#  'London_eye/294833',
#  'London_eye/295319',
#  'London_eye/295726',
#  'London_eye/295816',
#  'London_eye/296518',
#  'London_eye/297094',
#  'London_eye/297496',
#  'London_eye/298861',
#  'London_eye/300113',
#  'London_eye/300510',
#  'London_eye/30061',
#  'London_eye/303529',
#  'London_eye/303532',
#  'London_eye/303534',
#  'London_eye/304480',
#  'London_eye/307458',
#  'London_eye/309324',
#  'London_eye/312981',
#  'London_eye/313314',
#  'London_eye/314011',
#  'London_eye/316883',
#  'London_eye/320094',
#  'London_eye/320456',
#  'London_eye/321068',
#  'London_eye/321529',
#  'London_eye/321831',
#  'London_eye/331124',
#  'London_eye/332392',
#  'London_eye/338766',
#  'London_eye/339111',
#  'London_eye/339125',
#  'London_eye/340648',
#  'London_eye/342359',
#  'London_eye/346648',
#  'London_eye/34862',
#  'London_eye/352123',
#  'London_eye/353098',
#  'London_eye/354206',
#  'London_eye/354236',
#  'London_eye/354430',
#  'London_eye/355403',
#  'London_eye/355441',
#  'London_eye/355512',
#  'London_eye/355703',
#  'London_eye/356836',
#  'London_eye/357048',
#  'London_eye/357365',
#  'London_eye/357384',
#  'London_eye/357557',
#  'London_eye/357635',
#  'London_eye/358037',
#  'London_eye/359360',
#  'London_eye/359412',
#  'London_eye/359802',
#  'London_eye/359901',
#  'London_eye/360480',
#  'London_eye/36050',
#  'London_eye/360688',
#  'London_eye/360746',
#  'London_eye/360964',
#  'London_eye/361485',
#  'London_eye/361491',
#  'London_eye/361754',
#  'London_eye/361755',
#  'London_eye/363234',
#  'London_eye/363985',
#  'London_eye/364496',
#  'London_eye/365368',
#  'London_eye/365580',
#  'London_eye/365859',
#  'London_eye/366193',
#  'London_eye/366328',
#  'London_eye/366593',
#  'London_eye/366597',
#  'London_eye/367514',
#  'London_eye/367663',
#  'London_eye/368551',
#  'London_eye/369221',
#  'London_eye/369694',
#  'London_eye/369727',
#  'London_eye/369728',
#  'London_eye/369752',
#  'London_eye/369793',
#  'London_eye/369981',
#  'London_eye/372269',
#  'London_eye/372435',
#  'London_eye/373185',
#  'London_eye/373409',
#  'London_eye/373704',
#  'London_eye/374083',
#  'London_eye/374157',
#  'London_eye/375981',
#  'London_eye/376840',
#  'London_eye/377027',
#  'London_eye/378695',
#  'London_eye/378991',
#  'London_eye/379142',
#  'London_eye/379336',
#  'London_eye/379554',
#  'London_eye/379753',
#  'London_eye/379831',
#  'London_eye/379890',
#  'London_eye/380016',
#  'London_eye/380087',
#  'London_eye/380290',
#  'London_eye/380303',
#  'London_eye/380611',
#  'London_eye/380772',
#  'London_eye/381149',
#  'London_eye/381592',
#  'London_eye/381862',
#  'London_eye/382125',
#  'London_eye/382368',
#  'London_eye/382499',
#  'London_eye/382696',
#  'London_eye/382713',
#  'London_eye/382817',
#  'London_eye/383226',
#  'London_eye/383480',
#  'London_eye/383485',
#  'London_eye/383774',
#  'London_eye/384029',
#  'London_eye/384131',
#  'London_eye/384446',
#  'London_eye/384451',
#  'London_eye/384466',
#  'London_eye/384754',
#  'London_eye/384982',
#  'London_eye/385386',
#  'London_eye/385968',
#  'London_eye/386303',
#  'London_eye/386352',
#  'London_eye/386511',
#  'London_eye/387349',
#  'London_eye/387385',
#  'London_eye/387552',
#  'London_eye/387771',
#  'London_eye/387973',
#  'London_eye/388013',
#  'London_eye/388671',
#  'London_eye/388718',
#  'London_eye/388725',
#  'London_eye/389016',
#  'London_eye/389181',
#  'London_eye/389197',
#  'London_eye/389450',
#  'London_eye/389595',
#  'London_eye/390771',
#  'London_eye/391148',
#  'London_eye/391574',
#  'London_eye/391637',
#  'London_eye/391640',
#  'London_eye/392240',
#  'London_eye/392248',
#  'London_eye/392252',
#  'London_eye/393683',
#  'London_eye/393715',
#  'London_eye/393963',
#  'London_eye/394705',
#  'London_eye/395300',
#  'London_eye/395388',
#  'London_eye/395912',
#  'London_eye/396759',
#  'London_eye/397020',
#  'London_eye/397021',
#  'London_eye/397121',
#  'London_eye/398334',
#  'London_eye/399937',
#  'London_eye/400159',
#  'London_eye/400886',
#  'London_eye/401125',
#  'London_eye/401241',
#  'London_eye/402071',
#  'London_eye/402830',
#  'London_eye/403080',
#  'London_eye/404031',
#  'London_eye/405058',
#  'London_eye/405630',
#  'London_eye/406096',
#  'London_eye/408270',
#  'London_eye/409301',
#  'London_eye/411088',
#  'London_eye/411148',
#  'London_eye/411377',
#  'London_eye/411410',
#  'London_eye/411431',
#  'London_eye/412173',
#  'London_eye/413681',
#  'London_eye/414060',
#  'London_eye/414992',
#  'London_eye/415870',
#  'London_eye/416044',
#  'London_eye/416535',
#  'London_eye/417065',
#  'London_eye/417383',
#  'London_eye/417427',
#  'London_eye/418870',
#  'London_eye/421197',
#  'London_eye/438035',
#  'London_eye/440231',
#  'London_eye/443892',
#  'London_eye/450865',
#  'London_eye/453770',
#  'London_eye/454164',
#  'London_eye/454181',
#  'London_eye/459122',
#  'London_eye/464686',
#  'London_eye/464697',
#  'London_eye/464733',
#  'London_eye/467190',
#  'London_eye/470984',
#  'London_eye/473609',
#  'London_eye/475048',
#  'London_eye/477739',
#  'London_eye/480417',
#  'London_eye/480742',
#  'London_eye/480746',
#  'London_eye/485975',
#  'London_eye/486458',
#  'London_eye/486459',
#  'London_eye/486620',
#  'London_eye/487486',
#  'London_eye/488236',
#  'London_eye/488242',
#  'London_eye/488461',
#  'London_eye/494481',
#  'London_eye/498351',
#  'London_eye/500274',
#  'London_eye/500312',
#  'London_eye/500870',
#  'London_eye/500871',
#  'London_eye/500982',
#  'London_eye/501839',
#  'London_eye/502169',
#  'London_eye/504987',
#  'London_eye/506595',
#  'London_eye/506948',
#  'London_eye/508633',
#  'London_eye/510033',
#  'London_eye/510507',
#  'London_eye/511597',
#  'London_eye/512428',
#  'London_eye/513849',
#  'London_eye/515283',
#  'London_eye/517500',
#  'London_eye/534805',
#  'London_eye/535054',
#  'London_eye/536444',
#  'London_eye/536520',
#  'London_eye/536522',
#  'London_eye/539829',
#  'London_eye/540703',
#  'London_eye/542210',
#  'London_eye/542223',
#  'London_eye/544333',
#  'London_eye/546440',
#  'London_eye/549298',
#  'London_eye/554872',
#  'London_eye/559275',
#  'London_eye/562304',
#  'London_eye/562312',
#  'London_eye/562320',
#  'London_eye/567972',
#  'London_eye/571868',
#  'London_eye/5734',
#  'London_eye/575889',
#  'London_eye/577597',
#  'London_eye/581066',
#  'London_eye/582609',
#  'London_eye/583047',
#  'London_eye/586025',
#  'London_eye/586241',
#  'London_eye/587302',
#  'London_eye/587634',
#  'London_eye/587743',
#  'London_eye/592049',
#  'London_eye/595793',
#  'London_eye/595796',
#  'London_eye/59867',
#  'London_eye/599923',
#  'London_eye/605296',
#  'London_eye/605325',
#  'London_eye/606961',
#  'London_eye/608477',
#  'London_eye/612016',
#  'London_eye/612851',
#  'London_eye/613100',
#  'London_eye/613485',
#  'London_eye/613552',
#  'London_eye/613830',
#  'London_eye/614216',
#  'London_eye/614926',
#  'London_eye/616709',
#  'London_eye/618916',
#  'London_eye/619110',
#  'London_eye/619676',
#  'London_eye/624883',
#  'London_eye/628183',
#  'London_eye/629654',
#  'London_eye/631470',
#  'London_eye/635410',
#  'London_eye/635483',
#  'London_eye/636016',
#  'London_eye/636063',
#  'London_eye/636359',
#  'London_eye/639294',
#  'London_eye/640339',
#  'London_eye/640470',
#  'London_eye/640911',
#  'London_eye/644045',
#  'London_eye/647118',
#  'London_eye/648071',
#  'London_eye/648775',
#  'London_eye/650654',
#  'London_eye/650740',
#  'London_eye/651755',
#  'London_eye/651758',
#  'London_eye/652157',
#  'London_eye/653531',
#  'London_eye/653535',
#  'London_eye/653721',
#  'London_eye/653731',
#  'London_eye/653741',
#  'London_eye/654180',
#  'London_eye/654277',
#  'London_eye/655545',
#  'London_eye/655546',
#  'London_eye/655547',
#  'London_eye/655593',
#  'London_eye/656396',
#  'London_eye/656510',
#  'London_eye/657043',
#  'London_eye/657044',
#  'London_eye/657045',
#  'London_eye/657301',
#  'London_eye/657618',
#  'London_eye/658397',
#  'London_eye/658895',
#  'London_eye/660445',
#  'London_eye/661471',
#  'London_eye/661820',
#  'London_eye/662504',
#  'London_eye/6626',
#  'London_eye/663727',
#  'London_eye/665668',
#  'London_eye/666152',
#  'London_eye/666400',
#  'London_eye/666797',
#  'London_eye/667004',
#  'London_eye/667082',
#  'London_eye/667090',
#  'London_eye/667095',
#  'London_eye/668149',
#  'London_eye/669021',
#  'London_eye/669395',
#  'London_eye/673857',
#  'London_eye/674138',
#  'London_eye/674179',
#  'London_eye/676267',
#  'London_eye/677263',
#  'London_eye/678106',
#  'London_eye/679342',
#  'London_eye/681299',
#  'London_eye/681382',
#  'London_eye/682637',
#  'London_eye/682766',
#  'London_eye/683751',
#  'London_eye/683752',
#  'London_eye/686082',
#  'London_eye/688138',
#  'London_eye/688144',
#  'London_eye/689032',
#  'London_eye/690155',
#  'London_eye/691681',
#  'London_eye/692887',
#  'London_eye/693487',
#  'London_eye/693489',
#  'London_eye/693490',
#  'London_eye/694214',
#  'London_eye/695028',
#  'London_eye/695987',
#  'London_eye/698209',
#  'London_eye/699350',
#  'London_eye/699749',
#  'London_eye/700828',
#  'London_eye/701250',
#  'London_eye/701376',
#  'London_eye/703231',
#  'London_eye/703257',
#  'London_eye/703331',
#  'London_eye/703345',
#  'London_eye/703542',
#  'London_eye/704090',
#  'London_eye/704111',
#  'London_eye/704343',
#  'London_eye/707616',
#  'London_eye/708983',
#  'London_eye/709823',
#  'London_eye/710732',
#  'London_eye/711530',
#  'London_eye/711546',
#  'London_eye/712146',
#  'London_eye/713501',
#  'London_eye/714231',
#  'London_eye/714381',
#  'London_eye/714386',
#  'London_eye/715332',
#  'London_eye/715597',
#  'London_eye/717434',
#  'London_eye/717440',
#  'London_eye/718185',
#  'London_eye/718241',
#  'London_eye/718851',
#  'London_eye/719402',
#  'London_eye/719534',
#  'London_eye/719593',
#  'London_eye/720941',
#  'London_eye/720942',
#  'London_eye/720943',
#  'London_eye/720945',
#  'London_eye/720947',
#  'London_eye/725026',
#  'London_eye/725847',
#  'London_eye/726411',
#  'London_eye/727129',
#  'London_eye/727130',
#  'London_eye/729163',
#  'London_eye/73034',
#  'London_eye/730900',
#  'London_eye/734017',
#  'London_eye/734025',
#  'London_eye/734378',
#  'London_eye/735602',
#  'London_eye/735624',
#  'London_eye/737883',
#  'London_eye/737884',
#  'London_eye/738104',
#  'London_eye/738978',
#  'London_eye/740367',
#  'London_eye/741645',
#  'London_eye/741679',
#  'London_eye/741753',
#  'London_eye/742605',
#  'London_eye/742606',
#  'London_eye/742997',
#  'London_eye/743472',
#  'London_eye/744466',
#  'London_eye/745027',
#  'London_eye/745094',
#  'London_eye/74767',
#  'London_eye/747',
#  'London_eye/748950',
#  'London_eye/74951',
#  'London_eye/750180',
#  'London_eye/753999',
#  'London_eye/755199',
#  'London_eye/757024',
#  'London_eye/757029',
#  'London_eye/757310',
#  'London_eye/759464',
#  'London_eye/761438',
#  'London_eye/762444',
#  'London_eye/763614',
#  'London_eye/763770',
#  'London_eye/763771',
#  'London_eye/763933',
#  'London_eye/763934',
#  'London_eye/763955',
#  'London_eye/764044',
#  'London_eye/764471',
#  'London_eye/764701',
#  'London_eye/766378',
#  'London_eye/76731',
#  'London_eye/767366',
#  'London_eye/768646',
#  'London_eye/769117',
#  'London_eye/769118',
#  'London_eye/769119',
#  'London_eye/771474',
#  'London_eye/774605',
#  'London_eye/775932',
#  'London_eye/776821',
#  'London_eye/777463',
#  'London_eye/777469',
#  'London_eye/777506',
#  'London_eye/779577',
#  'London_eye/779579',
#  'London_eye/779583',
#  'London_eye/779594',
#  'London_eye/779599',
#  'London_eye/78161',
#  'London_eye/783277',
#  'London_eye/783349',
#  'London_eye/783451',
#  'London_eye/783456',
#  'London_eye/785627',
#  'London_eye/785727',
#  'London_eye/786597',
#  'London_eye/786608',
#  'London_eye/786609',
#  'London_eye/78661',
#  'London_eye/787289',
#  'London_eye/787290',
#  'London_eye/787291',
#  'London_eye/788679',
#  'London_eye/789570',
#  'London_eye/789943',
#  'London_eye/791027',
#  'London_eye/793541',
#  'London_eye/793547',
#  'London_eye/793688',
#  'London_eye/794250',
#  'London_eye/794624',
#  'London_eye/795199',
#  'London_eye/795530',
#  'London_eye/795608',
#  'London_eye/796301',
#  'London_eye/796348',
#  'London_eye/796665',
#  'London_eye/796683',
#  'London_eye/797296',
#  'London_eye/797853',
#  'London_eye/798294',
#  'London_eye/803922',
#  'London_eye/804743',
#  'London_eye/804825',
#  'London_eye/821322',
#  'London_eye/826548',
#  'London_eye/843496',
#  'London_eye/847506',
#  'London_eye/848012',
#  'London_eye/859319',
#  'London_eye/860465',
#  'London_eye/861802',
#  'London_eye/864119',
#  'London_eye/8649',
#  'London_eye/8650',
#  'London_eye/865679',
#  'London_eye/865680',
#  'London_eye/869564',
#  'London_eye/879239',
#  'London_eye/892315',
#  'London_eye/892425',
#  'London_eye/894155',
#  'London_eye/895205',
#  'London_eye/895911',
#  'London_eye/904719',
#  'London_eye/907005',
#  'London_eye/914624',
#  'London_eye/914851',
#  'London_eye/915026',
#  'London_eye/915101',
#  'London_eye/915102',
#  'London_eye/915111',
#  'London_eye/915116',
#  'London_eye/915127',
#  'London_eye/915333',
#  'London_eye/917723',
#  'London_eye/919732',
#  'London_eye/926250',
#  'London_eye/928326',
#  'London_eye/929506',
#  'London_eye/93008',
#  'London_eye/931447',
#  'London_eye/933273',
#  'London_eye/933888',
#  'London_eye/935736',
#  'London_eye/942370',
#  'London_eye/942853',
#  'London_eye/943208',
#  'London_eye/947406',
#  'London_eye/947417',
#  'London_eye/949464',
#  'London_eye/949477',
#  'London_eye/952051',
#  'London_eye/952724',
#  'London_eye/955261',
#  'London_eye/957913',
#  'London_eye/962044',
#  'London_eye/962163',
#  'London_eye/963559',
#  'London_eye/965431',
#  'London_eye/966898',
#  'London_eye/973560',
#  'London_eye/975779',
#  'London_eye/989408',
#  'London_eye/99541',
#  'London_eye/997207',
#  'moon/101719',
#  'moon/1020889',
#  'moon/1022437',
#  'moon/102256',
#  'moon/102389',
#  'moon/1060295',
#  'moon/106244',
#  'moon/106623',
#  'moon/106747',
#  'moon/106795',
#  'moon/107015',
#  'moon/107183',
#  'moon/107186',
#  'moon/107320',
#  'moon/107675',
#  'moon/108481',
#  'moon/109043',
#  'moon/109975',
#  'moon/110296',
#  'moon/110477',
#  'moon/110480',
#  'moon/110876',
#  'moon/110898',
#  'moon/110899',
#  'moon/110985',
#  'moon/111036',
#  'moon/111251',
#  'moon/111495',
#  'moon/111510',
#  'moon/111833',
#  'moon/111977',
#  'moon/112175',
#  'moon/112177',
#  'moon/112181',
#  'moon/112342',
#  'moon/112347',
#  'moon/112380',
#  'moon/112383',
#  'moon/112385',
#  'moon/112625',
#  'moon/112639',
#  'moon/112778',
#  'moon/114267',
#  'moon/114321',
#  'moon/115143',
#  'moon/115372',
#  'moon/115440',
#  'moon/115774',
#  'moon/116139',
#  'moon/116421',
#  'moon/116444',
#  'moon/116551',
#  'moon/117203',
#  'moon/117971',
#  'moon/117972',
#  'moon/119329',
#  'moon/119901',
#  'moon/120648',
#  'moon/120741',
#  'moon/122359',
#  'moon/123962',
#  'moon/124446',
#  'moon/124742',
#  'moon/125336',
#  'moon/125367',
#  'moon/125779',
#  'moon/126297',
#  'moon/126788',
#  'moon/126884',
#  'moon/126950',
#  'moon/126955',
#  'moon/126967',
#  'moon/127145',
#  'moon/127267',
#  'moon/127780',
#  'moon/128016',
#  'moon/128539',
#  'moon/128622',
#  'moon/128991',
#  'moon/129367',
#  'moon/129469',
#  'moon/129500',
#  'moon/129510',
#  'moon/129526',
#  'moon/129636',
#  'moon/129674',
#  'moon/129744',
#  'moon/129772',
#  'moon/129784',
#  'moon/129802',
#  'moon/129808',
#  'moon/130378',
#  'moon/130419',
#  'moon/130435',
#  'moon/130787',
#  'moon/130880',
#  'moon/131159',
#  'moon/131295',
#  'moon/131811',
#  'moon/131888',
#  'moon/132315',
#  'moon/132441',
#  'moon/132683',
#  'moon/132752',
#  'moon/133329',
#  'moon/133370',
#  'moon/133420',
#  'moon/133564',
#  'moon/133582',
#  'moon/133583',
#  ...]

# %%
len(real_relevant_image[1])
# Out:
# 1306

# %%
def mean_average_prescision(actual,ranking):
  precision=[]
  recall=[]
  count=0;
  n=len(actual)
  for i in range(len(ranking)):
    
    arr=ranking[i][0].split('.')
    
    if arr[0] in actual:
      count+=1
      recall.append(count/n)
      precision.append(count/(i+1))
    
  return (recall,precision)

# %%
def average_precison(recall,precision):
  n=len(recall)
  j=0;
  p={}
  average_precison=0
  for i in range(10):
    for k in range(n):
      if(((i+1)*10)>(recall[k]*100)):
        continue
      else:
        p[(i+1)*10]=precision[k]*100
        average_precison+=(precision[k]*100)
        break
  average_precison/=10
  return average_precison

# %%
def R_Precision(actual,ranking):
  r=0
  R=len(actual)
  for i in range(R):
    arr=ranking[i][0].split('.')
    
    if arr[0] in actual:
      r+=1
  r/=R
  return r

# %% [markdown]
# ## VGG16

# %%
import pickle
file=open('/content/drive/MyDrive/IR/new_Ranking/VGG16List.pkl','rb')
ranking_inception=pickle.load(file)
file.close()

# %%
maverage_precison=0
for filename,value in ranking_vgg16.items():
  index=filename.split('/')
  recall,precision=mean_average_prescision(sketch_ground_truth[int(index[1])],value)
  maverage_precison+=average_precison(recall,precision)
  # print(recall)
  # break
  # c+=1
maverage_precison/=len(ranking)
print("Maverage_precison = "+str(maverage_precison))
# Out:
# MAP = 21.99589421827739
